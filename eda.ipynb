# %%
# pip install odfpy

# %%
import pandas as pd
import numpy as np

# %%
# Load data
data = pd.read_excel('HCMC.ods', engine='odf')
data.head()
# Out:
#    Run  Approximate Duration (Minutes) Player Death Cause of Death  \
# 0    1                               2        Neuro        Creeper
# 1    2                               3        Neuro        Creeper
# 2    3                              30        Neuro         Spider
# 3    4                               7       Filian    Fall Damage
# 4    5                               7       Filian  Drowned (Mob)
#
#    Achievement: Acquire Hardware  Achievement: We Need to Go Deeper  \
# 0                          False                              False
# 1                          False                              False
# 2                           True                              False
# 3                           True                              False
# 4                           True                              False
#
#    Achievement: A Terrible Fortress  Achievement: Into Fire  \
# 0                             False                   False
# ...
